# %% [markdown]
# <a href="https://colab.research.google.com/github/BangYuHan/knu_bdna_2022/blob/main/%EB%B0%A9%EC%9C%A0%ED%95%9C5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {'age': [24, 22, 23, 16], 'name': ['유한', '로희', '희영', '은결'], 'height': [177.5, 158.8, 159.0, 171.2]}
x = pd.DataFrame(data, columns = ['name', 'age', 'height'])
x
# Out:
#   name  age  height
# 0   유한   24   177.5
# 1   로희   22   158.8
# 2   희영   23   159.0
# 3   은결   16   171.2

# %%
x.loc[4]=['두팔', 34, 185.2]
x
# Out:
#   name  age  height
# 0   유한   24   177.5
# 1   로희   22   158.8
# 2   희영   23   159.0
# 3   은결   16   171.2
# 4   두팔   34   185.2

# %%
y = pd.DataFrame({'age':[27], 'name': ['상확'], 'height': 170.1 }, columns=['age', 'name', 'height'])
y
# Out:
#    age name  height
# 0   27   상확   170.1

# %%
result = x.append(y)

# %%
result
# Out:
#   name  age  height
# 0   유한   24   177.5
# 1   로희   22   158.8
# 2   희영   23   159.0
# 3   은결   16   171.2
# 4   두팔   34   185.2
# 0   상확   27   170.1

# %%
result=x.append(y, ignore_index=True)
result
# Out:
#   name  age  height
# 0   유한   24   177.5
# 1   로희   22   158.8
# 2   희영   23   159.0
# 3   은결   16   171.2
# 4   두팔   34   185.2
# 5   상확   27   170.1

# %%
x = x.append(y, ignore_index=True)
x
# Out:
#   name  age  height
# 0   유한   24   177.5
# 1   로희   22   158.8
# 2   희영   23   159.0
# 3   은결   16   171.2
# 4   두팔   34   185.2
# 5   상확   27   170.1

# %%
result = pd.concat([x,y], ignore_index=True)

# %%
result
# Out:
#   name  age  height
# 0   유한   24   177.5
# 1   로희   22   158.8
# 2   희영   23   159.0
# 3   은결   16   171.2
# 4   두팔   34   185.2
# 5   상확   27   170.1
# 6   상확   27   170.1

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0 -1.016272  0.508862  0.009707  1.023543  0.606501
# 1 -1.632574       NaN -1.165795  1.007242  0.876889
# 2  0.502996 -0.152375       NaN -1.045587 -0.103226
# 3 -1.230458 -0.077020  0.908526  1.620093  2.043647
# 4 -1.252073 -2.082687  0.168576  0.616250 -0.290986

# %%
df.isnull()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False   True  False  False  False
# 2  False  False   True  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
df['A'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: A, dtype: bool

# %%
df['B'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: B, dtype: bool

# %%
df['C'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: C, dtype: bool

# %%
df[df['B'].isnull()]
# Out:
#           A   B         C         D         E
# 1 -1.632574 NaN -1.165795  1.007242  0.876889

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    1
# D    0
# E    0
# dtype: int64

# %%
df['B'].isnull().sum()
# Out:
# 1

# %%
df.dropna()
# Out:
#           A         B         C         D         E
# 0 -1.016272  0.508862  0.009707  1.023543  0.606501
# 3 -1.230458 -0.077020  0.908526  1.620093  2.043647
# 4 -1.252073 -2.082687  0.168576  0.616250 -0.290986

# %%
df.dropna(inplace=True)
df
# Out:
#           A         B         C         D         E
# 0 -1.016272  0.508862  0.009707  1.023543  0.606501
# 3 -1.230458 -0.077020  0.908526  1.620093  2.043647
# 4 -1.252073 -2.082687  0.168576  0.616250 -0.290986

# %%
df=pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0  0.531822  0.826642 -0.263523  1.150468  0.058279
# 1  1.291792       NaN -0.466553  1.669306  1.253117
# 2 -1.557455  1.270484       NaN -0.077994  0.059554
# 3 -0.648453  1.578268  0.064165 -0.164908  0.184794
# 4  0.187119  0.750098 -0.383463 -1.550617  0.987593

# %%
df.dropna(subset=['B'], axis=0, inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  0.531822  0.826642 -0.263523  1.150468  0.058279
# 2 -1.557455  1.270484       NaN -0.077994  0.059554
# 3 -0.648453  1.578268  0.064165 -0.164908  0.184794
# 4  0.187119  0.750098 -0.383463 -1.550617  0.987593

# %%
df=pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0  0.463454  0.811421 -0.026595  0.525836  0.190896
# 1 -0.530972       NaN  0.756770 -0.268368 -0.003724
# 2 -1.337410 -1.456853       NaN -0.979190 -0.676457
# 3 -0.298656 -0.000315  1.216885 -0.527931 -0.216616
# 4  0.457033 -0.851201 -0.980241 -1.622432 -1.519432

# %%
df.dropna(axis=1, inplace=True)
df
# Out:
#           A         D         E
# 0  0.463454  0.525836  0.190896
# 1 -0.530972 -0.268368 -0.003724
# 2 -1.337410 -0.979190 -0.676457
# 3 -0.298656 -0.527931 -0.216616
# 4  0.457033 -1.622432 -1.519432

# %%
robots = [[24, 23680], [35, np.nan],[46, 47350], [27,np.nan]]
data = pd.DataFrame(robots, columns=['max_spped','price'])
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      NaN
# 2         46  47350.0
# 3         27      NaN

# %%
data.replace(np.nan, 0, inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean = data['price'].mean()
data.replace(np.nan, mean, inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean = data['price'].mean()
data.replace(np.nan, mean)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
# !plp3 install seaborn
# Out:
# /bin/bash: plp3: command not found

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

# %%
vals = iris['sepal_length'].values
sns.kdeplot(vals)
plt.title("kdeplot for sepal length")
plt.show()

# %%
vals = iris['petal_length'].values
sns.kdeplot(vals)
plt.title("kdeplot for petal length")
plt.show()

# %%
vals = iris['petal_length'].values
sns.distplot(vals, kde=True, rug=True)
plt.title("distplot for petal length")
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show>

# %%
sns.displot(vals, kde=True, rug=True)
plt.title("displot for petal length")
plt.show()

# %%
sns.rugplot(vals)

# %%
sns.histplot(vals, kde=True)
plt.title("histplot for petal length")
plt.show()
